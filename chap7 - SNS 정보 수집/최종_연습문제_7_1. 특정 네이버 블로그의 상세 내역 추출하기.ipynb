# %%
# 연습문제 : 네이버 블로그 정보 추출하여 다양한 형식의 파일로 저장하기
# 연습용 블로그 : https://blog.naver.com/hy820715/221514204265
print("=" *80)
print(" 연습문제 : 네이버 블로그 상세 내역과 댓글 정보 추출하여 저장하기")
print("=" *80)


#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time
import sys
import re
import math
import numpy 
import pandas as pd  
import random
import os   
import urllib.request
import urllib

#Step 2. 사용자로부터 필요한 정보 입력받기
#blog_url = input('1.크롤링할 블로그 주소를 입력하세요: ')
blog_url = 'https://blog.naver.com/hy820715/221514204265'
query_txt1 = '블로그댓글수집'
    
f_dir = input("2.결과 파일을 저장할 폴더명만 쓰세요(예:c:\\py_temp\\):")
if f_dir == '' :
    f_dir="c:\\py_temp\\"
    
print("\n")

print("요청하신 데이터를 수집 중입니다")
print("\n")
print("잠시만 기다려 주세요~~~~~^^")
print("\n")
    
# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt1)
os.chdir(f_dir+s+'-'+query_txt1)

ff_name=f_dir+s+'-'+query_txt1+'\\'+s+'-'+query_txt1+'.txt'
fc_name=f_dir+s+'-'+query_txt1+'\\'+s+'-'+query_txt1+'.csv'
fx_name=f_dir+s+'-'+query_txt1+'\\'+s+'-'+query_txt1+'.xlsx'

#Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.

s_time = time.time( )

s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)


blog_addr2=[]
w_name2=[]
w_date2=[]
blog_txt2=[]

reple_1st_name=[]    # 1차 댓글 작성자이름
reple_1st_txt=[]     # 1차 댓글 내용
reple_1st_date=[]    # 1차 댓글 날짜

reple_2nd_name=[]    # 2차 댓글 작성자이름
reple_2nd_txt=[]     # 2차 댓글 내용
reple_2nd_date=[]    # 2차 댓글 날짜


gubun = re.split("[/]",blog_url)

if gubun[2] != 'blog.naver.com' :
    print(" 네이버 블로그만 가능합니다")
    
else :
    driver.get(blog_url)
    time.sleep(random.randrange(2,5))  # 2 - 5 초 사이에 랜덤으로 시간 선택
      
    #Step 9. 각 블로그의 상세 결과를 출력하여 파일에 저장하기

    print("\n")
    print("텍스트 추출 시작 =================================================")
    print("\n")

    #try: 
    driver.switch_to.frame('mainFrame')
    #except:
    #    continue
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    addr_1 = soup.select('#postViewArea')
    addr_2 = soup.select('div[class="se-main-container"]')
       

    if addr_1 :

        f = open(ff_name, 'a',encoding='UTF-8')

        print("=" *80)             
        print("1.블로그주소: ",blog_url)
        blog_addr2.append(blog_url)
        f.write("\n")

        f.write("블로그 데이터를 수집합니다==============" + "\n")

        f.write("1.블로그 주소:"+blog_url + "\n")

        writer = soup.select("div.blog2_container > span.writer")
        try :
            wname = writer[0].get_text( )   # 작성자 닉네임
        except IndexError :
            wname = " "
        else :
            wname = wname.replace("\n","")
        print("2.작성자 닉네임: ",wname )
        f.write("2.작자 닉성네임:" + wname + "\n")
        w_name2.append(wname)

        wdate = soup.select('p[class="date fil5 pcol2 _postAddDate"]')
        try : 
            wdate = wdate[0].get_text( )
        except IndexError :
            wdate = ' '
        print("3.작성일자:",wdate)
        f.write("3.작성 일자:" + wdate + "\n")
        w_date2.append(wdate)

        for i in addr_1:
            for tag in soup.find_all('div',{'class':'se_component se_map default'}) :
            #for tag in soup.find_all('div',{'class':'se_component se_oglink og_bSize '}) :
                        tag.decompose()
            for tag2 in soup.find_all('div',{'class':'se_component se_oglink default '}) :
                        tag2.decompose()
            blog_txt = i.text.replace("\n","")

            try :
                print("4.블로그내용: \n",blog_txt)
            except UnicodeEncodeError :
                continue

            if len(blog_txt) > 32767 :
                blog_txt = blog_txt[1:32760]

            print("\n")
            f.write("4.블로그 내용:" + blog_txt + "\n")
            blog_txt2.append(blog_txt)

        time.sleep(1)

        f.close( )               

    elif addr_2 :
            
        print(" 블로그 데이터를 수집합니다==============" )

        f = open(ff_name, 'a',encoding='UTF-8')
        print("=" *80)    
        print("1.블로그주소: ",blog_url)
        blog_addr2.append(blog_url)
        f.write("\n")
        f.write("블로그 데이터를 수집합니다=============="  + "\n")

        f.write("1.블로그 주소:"+blog_url + "\n")

        writer = soup.select("div.blog2_container > span.writer")
        try :
            wname = writer[0].get_text( )   # 작성자 닉네임
        except IndexError :
            wname = " "
        else :
            wname = wname.replace("\n","")

        print("2.작성자 닉네임: ",wname )
        f.write("2.작성자 닉네임:" + wname + "\n")
        w_name2.append(wname)

        wdate = soup.select("div.blog2_container > span.se_publishDate.pcol2")
        try : 
            wdate = wdate[0].get_text( )
        except IndexError :
            wdate = " "

        print("3.작성일자:",wdate)
        f.write("3.작성 일자:" + wdate + "\n")
        w_date2.append(wdate)

        for i in addr_2:

            map_1 = soup.select('div[class="se_component se_map default"]')
            map_2 = soup.select('div[class="se_component se_oglink og_bSize "]')

            if map_1 :
                for tag in soup.find_all('div',{'class':'se_component se_map default'}) :
                        tag.decompose()

            elif map_2 :
                for tag2 in soup.find_all('div',{'class':'se_component se_oglink og_bSize '}) :
                        tag2.decompose()               

            blog_txt = i.text.replace("\n","")

            # 블로그 내용 출력중에 UnicodeEncodeError: 'UCS-2' codec can't encode characters.. 라는
            # 에러가 나올 경우가 있다. 이럴 때를 대비해서 예외처리를 해야 한다
            try :
                print("4.블로그내용: \n",blog_txt)
            except UnicodeEncodeError :
                continue

            if len(blog_txt) > 32767 :
                blog_txt = blog_txt[1:32760]

            print("\n")
            f.write("4.블로그 내용:" + blog_txt + "\n")
            blog_txt2.append(blog_txt)


            # 이미지 저장
            img_no = 1
            img_src1 = soup.find('div','se-main-container').find_all('img')
            for img in img_src1 :
                img_src2 = img['src']
                print(img_src2)
                urllib.request.urlretrieve(urllib.parse.quote(img_src2.encode('utf8'), '/:'),str(img_no)+'.jpg')
                                        
                print(img_no , '-이미지 저장 완료')
                img_no += 1

        f.close()          

e_time = time.time( )
t_time = e_time - s_time


print("\n") 
print("=" *100)
print("총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("파일 저장 완료: txt 파일명 : %s " %ff_name)
print("파일 저장 완료: csv 파일명 : %s " %fc_name)
print("파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *100)

driver.close()
# Out:
# ================================================================================
#  연습문제 : 네이버 블로그 상세 내역과 댓글 정보 추출하여 저장하기
# ================================================================================
# 2.결과 파일을 저장할 폴더명만 쓰세요(예:c:\py_temp\):
# 요청하신 데이터를 수집 중입니다
#
#
# 잠시만 기다려 주세요~~~~~^^
#
#
#
#
# 텍스트 추출 시작 =================================================
#
#
#  블로그 데이터를 수집합니다==============
# ================================================================================
# 1.블로그주소:  https://blog.naver.com/hy820715/221514204265
# 2.작성자 닉네임:  가치랩장입니다 ・ 2019. 4. 15. 16:27
# 3.작성일자:
# 4.블로그내용:
#  웹 크롤링 진짜 많이 재미있죠?웹 크롤링에 대한 다양한 예제는 바로 이 책에 들어 있어요~ 이 책안에는 다양한 유형의 웹사이트를 파이썬과 셀레니움을 활용하여 수집하는 노하우들이 다 들어 있습니다~하나씩 하나씩 따라하다 보면 금방 실력자가 되어 있으실 거예요~~^^​그리고 데이터베이스에 데이터를 저장한 후 조회하여 분석하는 경우도 많아서 많은 기업들이 데이터분석가나 인공지능 관련 분석가를 찾을 때SQL 언어 사용 능력도 많이 요구합니다~~SQL 관련 내용은 아래의 책을 보시면 완전 쉽지만 실무에서 많이 사용하는 다양한 기법들을 배우실 수 있을거예요~~[ 오라클 기반 SQL 책 ] [ MySQL 기반 책 ] ​무엇보다도 절대로 포기하지 말고 열공하는 자세가 가장 중요합니다~~^^열공해 주세요~~^^​가치랩장 드림.​​​
#
#
# https://postfiles.pstatic.net/MjAyMjExMjdfNDgg/MDAxNjY5NTA0MjQ1Mzg4.SiL0_-t6tL6N53xJ2RQ0y3Wt5XmWv4GwJoHjBTovPhUg.sqrzxsCud_xiIzV_LCU0jc7eEaOJn4FxwkuCLXJPPYYg.PNG.hy820715/%EC%8A%AC%EA%B8%B0%EB%A1%9C%EC%9A%B4%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%83%9D%ED%99%9C%ED%91%9C%EC%A7%80_2D.png?type=w966
# 1 -이미지 저장 완료
# https://postfiles.pstatic.net/MjAyMjExMjdfODIg/MDAxNjY5NTA0NDYyOTY4.hZU4D_P6PRsIHvfUtFV04rC1BXRcDf3tArkktVEHqEAg.k2mFuAo8eCISG13zHIszxwOCruqPceluJnDK0hdIv94g.PNG.hy820715/image.png?type=w80_blur
# 2 -이미지 저장 완료
# https://postfiles.pstatic.net/MjAyMjExMjdfMTgg/MDAxNjY5NTA0NTk1NjAx.KakcXxi_xtqvCfMUro84LU9HKX7tJ6HJPX3hKZZfF8wg.9mqn0BwPVgb12vLD3ps8dLwHkUfVgXxhH1_7hDbfHc0g.PNG.hy820715/%ED%91%9C%EC%A7%80%EC%95%9E%EB%A9%B4.png?type=w80_blur
# 3 -이미지 저장 완료
#
#
# ====================================================================================================
# 총 소요시간은 7.1 초 입니다
# 파일 저장 완료: txt 파일명 : c:\py_temp\2026-03-09-09-31-45-블로그댓글수집\2026-03-09-09-31-45-블로그댓글수집.txt
# 파일 저장 완료: csv 파일명 : c:\py_temp\2026-03-09-09-31-45-블로그댓글수집\2026-03-09-09-31-45-블로그댓글수집.csv
# 파일 저장 완료: xls 파일명 : c:\py_temp\2026-03-09-09-31-45-블로그댓글수집\2026-03-09-09-31-45-블로그댓글수집.xlsx
# ====================================================================================================
