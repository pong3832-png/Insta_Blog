# %%
! pip install bs4
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## riss.kr 사이트에서 특정 키워드로 자동 검색하기 (전에 했던 내용)

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)
url = 'https://www.riss.kr/'
driver.get(url)
time.sleep(3)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")
# Out:
# ...
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ...
#
#
# ...

# %% [markdown]
# ## Step 5.학위 논문 선택하기

# %%
driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)

# %% [markdown]
# ## Step 6.Beautiful Soup 로 본문 내용만 추출하기

# %%
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

# %% [markdown]
# ## Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기

# %%
import sys
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')

orig_stdout = sys.stdout #sys.stdout여기에 모니터가 들어있고 변수 주는 이유는 백업해놓는거. 이거 중요***
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file #모니터에 출력하지 말고 file 에 출력해라 - 저장할 파일명이 여기로 감
for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()
sys.stdout = orig_stdout #원래대로 변경 - 다시 화면에 출력시켜라. 중요함*****

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

# %% [markdown]
# ## 태그 뒤 텍스트만 출력

# %%
content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))
# Out:
# In this paper, we will conduct in-depth research on the Prevention of hospital infection of respiratory infectious diseases, and in the future, we will conduct in-depth research on more hospitals to avoid and reduce hospital infection. It is hoped that the study will contribute to the avoidance and reduction of hospital infections of respiratory infectious diseases.xample analysis. According to the evaluation results and the actual specific situation of the hospital, preventive measures are put forward according to the hospital infection prevention standard level.Before the risk of nosocomial infection is serious, one pedestrian line and one motor vehicle line are set in the hospital. The underground access line to the treatment area is closed, which can reserve an entrance to the treatment area.When the risk of nosocomial infection is serious, the space is transformed. This can integrate the treatment area into a treatment area. A ground entrance is provided which can close the unde
# ...

# %%
import sys
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\riss.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()
sys.stdout = orig_stdout #원래대로 변경 - 다시 화면에 출력시켜라

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)
# Out:
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
# 수집된 결과는 전염병 에 저장되었습니다

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)
url = 'https://www.riss.kr/'
driver.get(url)
time.sleep(3)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)
# Out:
# ...
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ...

# %% [markdown]
# ## 연습문제 1
#
# 네이버 사이트에서 “서진수 빅데이터” 로 검색한 후 “뉴스” 카테고리를 선택하여 조회된 기사
# 들을 수집하여 txt 형식으로 저장하세요(단 파일경로와 이름은 자유롭게 선택하세요)

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)
url = 'https://www.naver.com/'
driver.get(url)
time.sleep(3)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

time.sleep(2)
driver.find_element(By.LINK_TEXT,'뉴스').click()
time.sleep(3)

#bs4로 본문내용 추출
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','sds-comps-vertical-layout sds-comps-full-layout fds-news-item-list-tab').find_all('div')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

    import sys
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\naver.txt): ')

orig_stdout = sys.stdout #sys.stdout여기에 모니터가 들어있고 변수 주는 이유는 백업해놓는거. 이거 중요***
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file #모니터에 출력하지 말고 file 에 출력해라 - 저장할 파일명이 여기로 감
for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()
sys.stdout = orig_stdout #원래대로 변경 - 다시 화면에 출력시켜라. 중요함*****

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

content_1 = soup_1.find('div','sds-comps-vertical-layout sds-comps-full-layout fds-news-item-list-tab').find_all('div')
for i in content_1 :
    print(i.get_text().replace("\n",""))
# Out:
# ...
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ...
#
#
# 베타뉴스2018.04.11.Keep에 저장Keep에 바로가기빅데이터 전문가 서진수, '강사양성' 직접 나선다해당 과정에 대한 내용은 오프라인 설명회에서 공개되며, 참가를 원하는 사람은 19일까지 온오프믹스 홈페이지(KBS 명견만리 서진수 직강 '빅데이터 전문강사 되기' 무료 세미나)를 통해 신청하면 된다. 서진수 대표에 대한 자세한 정보는 포털에 ‘서진수 홈페이지’ 검색 후 확인할 수 있다. [ 경제신문의...
#
#
# 베타뉴스2018.04.11.Keep에 저장Keep에 바로가기
#
#
# 베타뉴스2018.04.11.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 베타뉴스
#
#
# 2018.04.11.
#
#
# 2018.04.11.
#
#
# Keep에 저장Keep에 바로가기
#
#
# Keep에 저장Keep에 바로가기
#
#
# 빅데이터 전문가 서진수, '강사양성' 직접 나선다해당 과정에 대한 내용은 오프라인 설명회에서 공개되며, 참가를 원하는 사람은 19일까지 온오프믹스 홈페이지(KBS 명견만리 서진수 직강 '빅데이터 전문강사 되기' 무료 세미나)를 통해 신청하면 된다. 서진수 대표에 대한 자세한 정보는 포털에 ‘서진수 홈페이지’ 검색 후 확인할 수 있다. [ 경제신문의...
#
#
# 빅데이터 전문가 서진수, '강사양성' 직접 나선다해당 과정에 대한 내용은 오프라인 설명회에서 공개되며, 참가를 원하는 사람은 19일까지 온오프믹스 홈페이지(KBS 명견만리 서진수 직강 '빅데이터 전문강사 되기' 무료 세미나)를 통해 신청하면 된다. 서진수 대표에 대한 자세한 정보는 포털에 ‘서진수 홈페이지’ 검색 후 확인할 수 있다. [ 경제신문의...
#
#
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ## bs4 연습

# %%
ex2 = ''' 
<html> 
	<head> 
		<h1> 사야할 과일 
	</head> 
	<body> 
		<h1> 시장가서 사야할 과일 목록 
			<div> <p id='fruits1' class='name1' title='바나나'> 바나나 
				  <span class = 'price'> 3000원 </span> 
				  <span class = 'count'> 10개 </span> 
				  <span class = 'store'> 바나나가게 </span> 
				  <a href = 'https://www.banana.com'> banana.com </a> 
                              </p>
			</div> 
			<div> <p id='fruits2' class='name2' title='체리'> 체리 
				 <span class = 'price'> 100원 </span> 
				 <span class = 'count'> 50개 </span> 
				 <span class = 'store'> 체리가게</span> 
				 <a href = 'https://www.cherry.com'> cherry.com </a>
                               </p> 
			</div> 
			<div> <p id='fruits3' class='name3' title='오렌지'> 오렌지
				 <span class = 'price'> 500원 </span> 
				 <span class = 'count'> 20개 </span> 
				 <span class = 'store'> 오렌지가게</span> 
				 <a href = 'https://www.orange.com'> orange.com </a>
                              </p> 
			<div> 
	</body> 
</html> '''

soup2 = BeautifulSoup(ex2, 'html.parser')

# %%
soup2.select('p')
# Out:
# [<p class="name1" id="fruits1" title="바나나"> 바나나
#  				  <span class="price"> 3000원 </span>
#  <span class="count"> 10개 </span>
#  <span class="store"> 바나나가게 </span>
#  <a href="https://www.banana.com"> banana.com </a>
#  </p>,
#  <p class="name2" id="fruits2" title="체리"> 체리
#  				 <span class="price"> 100원 </span>
#  <span class="count"> 50개 </span>
#  <span class="store"> 체리가게</span>
#  <a href="https://www.cherry.com"> cherry.com </a>
#  </p>,
#  <p class="name3" id="fruits3" title="오렌지"> 오렌지
#  				 <span class="price"> 500원 </span>
#  <span class="count"> 20개 </span>
#  <span class="store"> 오렌지가게</span>
#  <a href="https://www.orange.com"> orange.com </a>
#  </p>]

# %%
soup2.select(' .name1')
# Out:
# [<p class="name1" id="fruits1" title="바나나"> 바나나
#  				  <span class="price"> 3000원 </span>
#  <span class="count"> 10개 </span>
#  <span class="store"> 바나나가게 </span>
#  <a href="https://www.banana.com"> banana.com </a>
#  </p>]

# %%
soup2.select(' div > p > span')
# Out:
# [<span class="price"> 3000원 </span>,
#  <span class="count"> 10개 </span>,
#  <span class="store"> 바나나가게 </span>,
#  <span class="price"> 100원 </span>,
#  <span class="count"> 50개 </span>,
#  <span class="store"> 체리가게</span>,
#  <span class="price"> 500원 </span>,
#  <span class="count"> 20개 </span>,
#  <span class="store"> 오렌지가게</span>]

# %%
soup2.select(' div > p > span') [0]
# Out:
# <span class="price"> 3000원 </span>

# %%
soup2.select(' div > p > span') [1]
# Out:
# <span class="count"> 10개 </span>

# %% [markdown]
# ## 연습문제 2
# 다음 사이트에서 “서진수 빅데이터” 로 검색한 후 “뉴스” 카테고리를 선택하여 조회된 기사들
# 을 수집하여 txt 형식으로 저장하세요(단 파일경로와 이름은 자유롭게 선택하세요)

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)
url = 'https://www.daum.net/'
driver.get(url)
time.sleep(3)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'q')
driver.find_element(By.ID,'q').click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

driver.find_element(By.LINK_TEXT,'뉴스').click()
time.sleep(2)

#bs4로 본문내용 추출
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('ul','c-list-basic').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

    import sys
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\daum.txt): ')

orig_stdout = sys.stdout #sys.stdout여기에 모니터가 들어있고 변수 주는 이유는 백업해놓는거. 이거 중요***
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file #모니터에 출력하지 말고 file 에 출력해라 - 저장할 파일명이 여기로 감
for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()
sys.stdout = orig_stdout #원래대로 변경 - 다시 화면에 출력시켜라. 중요함*****

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

content_1 = soup_1.find('ul','c-list-basic').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))
# Out:
# ...
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ...
#
#
# 뉴시스       개별문서메뉴  톡으로 바로 공유 공유하기                 '빅데이터 분석 전도사' 서진수 주목, 인문대생 멘토       【서울=뉴시스】유희연 기자 = 데이터 관리와 분석 전문가인 서진수가 빅데이터 활용 무료강연을 펼치고 있다. 그는 데이터 관련 분야에서 15년 정도 종사하면서 다양한 기업체의 데이터베이스를 구축하고 운영, 분석해왔다. 오라클 SQL과 PL/SQL, 오라클 관리실무...    2015.05.04
#
#
# 연합뉴스       개별문서메뉴  톡으로 바로 공유 공유하기                 '빅데이터 분석 전도사' 서진수, 무료 강연 진행       ▲도서출판더알음(대표 서진수)은 빅데이터 활용과 관련해 대학교와 대학원, 회사 등에서 무료 지식특강을 진행한다고 20일 밝혔다. 입문자와 초보자를 위한 빅데이터 분석 방법을 다루는 이번 강의는 취업난을 겪고 있는 인문계열 학생들을 위해 기획됐다. 최근...    2015.05.20
#
#
# SBS Biz       개별문서메뉴  톡으로 바로 공유 공유하기                 빅데이터 전문가 서진수 청년들의 희망 멘토로 강단 서다       직장인들에게 작은 도움이 되고자 여러 대학교와 대학원, 회사 등을 방문해 무료 특강을 진행하고 있는 것이다. 저자 서진수는 "빅데이터는 앞으로 산업 분야를 가리지 않고 우리가 사는 미래를 예측할 수 있는 도구가 될 것"이라고 예상하면서 "데이터 분석에 입문...    2015.05.18
#
#
# ...

# %% [markdown]
# ## 연습문제 3
# 한국관광공사의 대한민국 구석구석 사이트(https://korean.visitkorea.or.kr) 에서 “여름여행” 키워
# 드로 검색한 후 화면 오른쪽의 “어제의 인기 검색어” 목록을 수집하여 txt 형식으로 저장하세요.
# (단 파일경로와 이름은 자유롭게 선택하세요)

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)
url = 'https://korean.visitkorea.or.kr/main/main.do'
driver.get(url)
time.sleep(3)
driver.maximize_window()
time.sleep(10)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'headerSearchBtn')
driver.find_element(By.ID,'headerSearchBtn').click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

#bs4로 본문내용 추출
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')
time.sleep(3)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'inp_search_index')
driver.find_element(By.ID,'inp_search_index').click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

driver.find_element(By.LINK_TEXT,'동의').click()
time.sleep(5)

# 원래 창으로 돌아가기
driver.switch_to.window(driver.window_handles[0])
time.sleep(2)

html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('ul','popular_search_list').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

    import sys
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\구석구석.txt): ')

orig_stdout = sys.stdout #sys.stdout여기에 모니터가 들어있고 변수 주는 이유는 백업해놓는거. 이거 중요***
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file #모니터에 출력하지 말고 file 에 출력해라 - 저장할 파일명이 여기로 감
for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()
sys.stdout = orig_stdout #원래대로 변경 - 다시 화면에 출력시켜라. 중요함*****

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

content_1 = soup_1.find('ul','popular_search_list').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))
# Out:
# ...
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ...
# 1 반값여행
#
#
# 2 경주
#
#
# 3 강릉
#
#
# 4 단양
#
#
# 5 부산
#
#
# 6 지역사랑 휴가지원
#
#
# 7 영월
#
#
# 8 안동
#
#
# 9 제천
#
#
# 10 속초
#
#
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
# 수집된 결과는 c:\\py_temp\\구석구석(팝업냅둠).txt 에 저장되었습니다
# 1반값여행
# 2경주
# 3강릉
# 4단양
# 5부산
# 6지역사랑 휴가지원
# 7영월
# 8안동
# 9제천
# 10속초

# %% [markdown]
# ## 연습문제 3 (XPATH 사용)

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)
url = 'https://korean.visitkorea.or.kr/main/main.do'
driver.get(url)
time.sleep(3)
driver.maximize_window()
time.sleep(10)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.XPATH,'//*[@id="headerSearchBtn"]')
driver.find_element(By.XPATH,'//*[@id="headerSearchBtn"]').click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

#bs4로 본문내용 추출
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')
time.sleep(3)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.XPATH,'//*[@id="inp_search_index"]')
driver.find_element(By.XPATH,'//*[@id="inp_search_index"]').click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

driver.find_element(By.LINK_TEXT,'동의').click()
time.sleep(5)

# 원래 창으로 돌아가기
driver.switch_to.window(driver.window_handles[0])
time.sleep(2)

html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('ul','popular_search_list').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

    import sys
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\구석구석.txt): ')

orig_stdout = sys.stdout #sys.stdout여기에 모니터가 들어있고 변수 주는 이유는 백업해놓는거. 이거 중요***
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file #모니터에 출력하지 말고 file 에 출력해라 - 저장할 파일명이 여기로 감
for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()
sys.stdout = orig_stdout #원래대로 변경 - 다시 화면에 출력시켜라. 중요함*****

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

content_1 = soup_1.find('ul','popular_search_list').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))
# Out:
# ...
#  이 크롤러는 riss 사이트의 논문 자료 수집용 웹크롤러입니다.
# ...
#
#
# 1 반값여행
#
#
# 2 경주
#
#
# 3 강릉
#
#
# 4 단양
#
#
# 5 부산
#
#
# 6 지역사랑 휴가지원
#
#
# 7 영월
#
#
# 8 안동
#
#
# 9 제천
#
#
# 10 속초
#
#
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
# 수집된 결과는 c:\\py_temp\\구석구석(XPATH 활용).txt 에 저장되었습니다
# 1반값여행
# 2경주
# 3강릉
# 4단양
# 5부산
# 6지역사랑 휴가지원
# 7영월
# 8안동
# 9제천
# 10속초

# %% [markdown]
# ## 연습문제3 - 글자만 뽑기

# %%
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 해양자원): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)
url = 'https://korean.visitkorea.or.kr/main/main.do'
driver.get(url)
time.sleep(3)
driver.maximize_window()
time.sleep(10)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.XPATH,'//*[@id="headerSearchBtn"]')
driver.find_element(By.XPATH,'//*[@id="headerSearchBtn"]').click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

#bs4로 본문내용 추출
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')
time.sleep(3)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.XPATH,'//*[@id="inp_search_index"]')
driver.find_element(By.XPATH,'//*[@id="inp_search_index"]').click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

driver.find_element(By.LINK_TEXT,'동의').click()
time.sleep(5)

html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('ul','popular_search_list').find_all('li')
for i in content_1 :
    print(i.find('span').get_text().replace("\n"," ").strip())
# Out:
# 반값여행
# 지역사랑 휴가지원
# 경주
# 단양
# 영월
# 강릉
# 부산
# 제천
# 안동
# 속초

# %%
    import sys
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\구석구석.txt): ')

orig_stdout = sys.stdout #sys.stdout여기에 모니터가 들어있고 변수 주는 이유는 백업해놓는거. 이거 중요***
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file #모니터에 출력하지 말고 file 에 출력해라 - 저장할 파일명이 여기로 감
for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()
sys.stdout = orig_stdout #원래대로 변경 - 다시 화면에 출력시켜라. 중요함*****

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

content_1 = soup_1.find('ul','popular_search_list').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))
