# %%
import pyautogui
w,h = pyautogui.size()
print('가로={0}, 세로={1}'.format(w,h))
# Out:
# 가로=1920, 세로=1200

# %%
import time
x, y = pyautogui.position()

print('x축위치값={0}, y축위치값={1}'.format(x,y))
time.sleep(3)
# Out:
# x축위치값=1493, y축위치값=398

# %%
pyautogui.moveTo(x=500,y=1000,duration=2)

# %%
pyautogui.click()

# %%
pyautogui.click(x=100, y=100)

# %%
pyautogui.click(button='right')

# %%
#마우스 다운(누른 상태)
pyautogui.mouseDown()

# %%
pyautogui.mouseDown('x축위치값=1493',y축위치값=398)

# %%
#마우스 업
pyautogui.mouseUp()

# %%
#특정 위치로 드래그 - 절대 좌표 사용
pyautogui.mouseDown(x=500, y=500)
pyautogui.mouseUp(x=200, y=200, duration=0.5)

# %%
#특정 위치로 드래그 - 절대 좌표 사용
pyautogui.mouseDown(x=960, y=400)

# %%
#삼각형 그리기
pyautogui.mouseDown(x=960, y=400)
pyautogui.dragTo(x=960, y=400, duration=1)
pyautogui.dragTo(x=640, y=800, duration=1)
pyautogui.dragTo(x=1280, y=800, duration=1)
pyautogui.dragTo(x=960, y=400, duration=2)
#pyautogui.mouseUp(x=960, y=400)

# %%
#별그리기
import pyautogui

# 1. 맨 위 꼭짓점에서 마우스 누르기
pyautogui.mouseDown(x=960, y=200)

# 2. 각 꼭짓점을 향해 순서대로 드래그하며 선 긋기
pyautogui.dragTo(x=1195, y=924, duration=1.5) # 오른쪽 아래로
pyautogui.dragTo(x=580, y=476, duration=1.5)  # 왼쪽 위로
pyautogui.dragTo(x=1340, y=476, duration=1.5) # 오른쪽 위로
pyautogui.dragTo(x=725, y=924, duration=1.5)  # 왼쪽 아래로
pyautogui.dragTo(x=960, y=200, duration=1.5)  # 다시 맨 위로 (완성)

# 3. 마우스 떼기
pyautogui.mouseUp(x=960, y=200)

# %%
#별그리기
import pyautogui

# 1. 맨 위 꼭짓점에서 마우스 누르기
pyautogui.mouseDown(x=960, y=200)

# 2. 각 꼭짓점을 향해 순서대로 드래그하며 선 긋기
pyautogui.dragTo(x=1195, y=924, duration=1.5) # 오른쪽 아래로
pyautogui.dragTo(x=580, y=476, duration=1.5)  # 왼쪽 위로
pyautogui.dragTo(x=1340, y=476, duration=1.5) # 오른쪽 위로
pyautogui.dragTo(x=725, y=924, duration=1.5)  # 왼쪽 아래로
pyautogui.dragTo(x=960, y=200, duration=1.5)  # 다시 맨 위로 (완성)

# 3. 마우스 떼기
pyautogui.mouseUp(x=960, y=200, duration=1)

#삼각형 그리기
pyautogui.mouseDown(x=960, y=500, duration=1)
pyautogui.dragTo(x=960, y=500, duration=1)
pyautogui.dragTo(x=860, y=650, duration=1)
pyautogui.dragTo(x=1060, y=650, duration=1)
pyautogui.dragTo(x=960, y=500, duration=1)

# %%
pyautogui.click(button='right')

# %%
#특정 위치로 드래그 (현재 위치 기준 상대 좌표 사용)
#쓰면 Down,moveTo,Up을 한번에!
#간지나게 할거면 나눠서 쓰삼.
pyautogui.dragTo(x=400, y=400, duration=2)

# %%
#마우스 휠 스크롤 아래로
pyautogui.scroll(-1000)

# %%
#마우스 휠 스크롤 위로
pyautogui.scroll(1000)
