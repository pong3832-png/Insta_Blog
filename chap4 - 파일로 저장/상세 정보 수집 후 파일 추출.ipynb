# %%
print("hello")
# Out:
# hello

# %%
# Chap 15.riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?: ')

#Step 3. 수집된 데이터를 저장할 파일 이름 입력 받기
f_dir = input("2.파일을 저장할 폴더명만 쓰세요(기본값:C:\\py_temp\\추출 후 파일 저장\\):")
if f_dir == '' :
    f_dir="C:\\py_temp\\추출 후 파일 저장\\"

#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'http://www.riss.kr/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

#Step 5. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
element.send_keys(query_txt)
element.send_keys("\n")

#Step 6.학위 논문 선택하기
driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)

#Step 7.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력 받기
import math
total_cnt = soup_1.find('div','searchBox pd').find('span','num').get_text()
print('키워드 %s (으)로 총 %s 건의 학위논문이 검색되었습니다' %(query_txt,total_cnt))
cnt = int(input('이 중에서 몇 건을 수집하시겠습니까?: '))
page_cnt = math.ceil(cnt / 10)
print('%s 건의 데이터를 수집하기 위해 %s 페이지의 게시물을 조회합니다.' %(cnt,page_cnt))
print("\n")
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# 키워드 전염병 (으)로 총 2,131 건의 학위논문이 검색되었습니다
# 22 건의 데이터를 수집하기 위해 3 페이지의 게시물을 조회합니다.

# %%
#Step 9. 데이터 수집하기
no2=[] # 게시글 번호 컬럼
title2=[ ] # 게시글 제목 컬럼
author2=[] # 논문 저자 컬럼
company2=[ ] # 소속 기관 컬럼
date2=[ ] # 게시글 날짜 컬럼
suksa2=[ ] # 국내석사 컬럼
contents2=[] # 초록내용
full_url2=[] # 논문 원본 URL

no = 1 # 게시글 번호 초기값

for a in range(1,page_cnt+1) :
    print("\n")
    print("%s 페이지 내용 수집 시작합니다 =======================" %a)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    content_list = soup.find('div','srchResultListW').find_all('li')

    for i in content_list:
        # 논문 제목 체크하기
        try:
            title=i.find('p','title').get_text().strip()
        except :
            continue
        else :
            # 1.게시글 번호
            print("\n")
            print("%s 번째 정보를 추출하고 있습니다============" %no)
            no2.append(no)
            print("1.번호 : %s" %no)

            # 2. 논문 제목
            title2.append(title.strip())
            print("2.제목 : %s" %title.strip())

            # 3. 작성자
            try :
                author=i.find('p','etc').find('span','writer').get_text().strip()
            except :
                author = '작성자가 없습니다'
                print("3.작성자 : %s" %author.strip())
                author2.append(author.strip())
            else :
                author2.append(author.strip())
                print("3.작성자 : %s" %author.strip())

            # 4. 소속기관
            try :
                company=i.find('p','etc').find('span','assigned').get_text().strip()
            except :
                company='소속 기관이 없습니다'
                company2.append(company.strip())
                print("4.소속기관 : %s" %company.strip())
            else :
                company2.append(company.strip())
                print("4.소속기관 : %s" %company.strip())

            # 5. 발표날짜
            try :
                date_1 =i.find('p','etc').find_all('span')
                date_2 = date_1[2].get_text().strip()
            except :
                date_2='발표날짜가 없습니다'
                date2.append(date_2)
                print("5.발표년도 : %s" %date_2)
            else :
                date2.append(date_2)
                print("5.발표년도 : %s" %date_2)

            # 6.학위여부
            try :
                suksa_1 =i.find('p','etc').find_all('span')
                suksa_2 = suksa_1[3].get_text().strip()
            except :
                suksa_2='학위가 없습니다'
                suksa2.append(suksa_2)
                print("6.학위여부 : %s" %suksa_2)
            else :
                suksa2.append(suksa_2)
                print("6.학위여부 : %s" %suksa_2)

            # 7.초록 내용-해당 논문의 상세 내역에서 추출할 수 있음.
            url_1 = i.find('p','title').find('a')['href']
            full_url = 'http://www.riss.kr'+url_1
            time.sleep(1)
            driver.get(full_url)

            html_1 = driver.page_source
            soup_1 = BeautifulSoup(html_1, 'html.parser')
            try :
                cont=soup_1.find("div","text").find('p').get_text().replace("\n","").strip()
            except :
                cont='초록이 없습니다'
                contents2.append(cont)
                print("7.초록내용 : %s" %cont)
            else :
                contents2.append(cont)
                print("7.초록내용 : %s" %cont)

            time.sleep(3)

            # 8.논문 url 주소
            full_url2.append(full_url)
            print('8.논문 URL 주소:' , full_url)

            driver.back() # 이전 페이지로 돌아가기

            time.sleep(3)

            no += 1

            if no > cnt :
                break

    a += 1
    b = str(a)

    try :
        driver.find_element(By.LINK_TEXT ,'%s' %b).click()
    except :
        driver.find_element(By.LINK_TEXT,'다음 페이지로').click()

print("요청하신 작업이 모두 완료되었습니다")
# Out:
# 1 페이지 내용 수집 시작합니다 =======================
#
#
# 1 번째 정보를 추출하고 있습니다============
# 1.번호 : 1
# 2.제목 : 전염병과 펜데믹 상황에서 메디컬 처치의 운영에 관한 연구
# 3.작성자 : 이재훈
# 4.소속기관 : 칼빈대학교 신학대학원
# 5.발표년도 : 2021
# 6.학위여부 : 국내석사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=2b51133ed1f648a9ffe0bdc3ef48d419&keyword=전염병
#
#
# 2 번째 정보를 추출하고 있습니다============
# 1.번호 : 2
# 2.제목 : 고등학생의 전염병 관련 과학적 소양 수준 연구
# 3.작성자 : 강보경
# 4.소속기관 : 慶尙大學校
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 과학적 소양(Scientific Literacy)은 현대 사회를 살아기는데 필수적인 수단으로 강조되고 있으며, 우리나라 제 7차 개정 과학과 교육과정의 목표로 제시되어있다. 본 연구에서는 고등학교 생명과...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=c6cab1a2133823bcffe0bdc3ef48d419&keyword=전염병
#
#
# 3 번째 정보를 추출하고 있습니다============
# 1.번호 : 3
# 2.제목 : 조선총독부의 급성전염병 예방 대책 변화 - 수인성 전염병을 중심으로
# 3.작성자 : 백선례
# 4.소속기관 : 한양대학교 대학원
# 5.발표년도 : 2021
# 6.학위여부 : 국내박사
# 7.초록내용 : 이 논문에서는 일본이 식민지 조선 통치의 정당성 부여에 적극 활용했던 근대 의학, 그 중에서도 급성전염병 예방 대책을 중점적으로 살펴보았다. 급성전염병 중에서도 식민지 조선에서 많...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=6365622b1979f82fffe0bdc3ef48d419&keyword=전염병
#
#
# 4 번째 정보를 추출하고 있습니다============
# 1.번호 : 4
# 2.제목 : 학령전 아동을 위한 호흡기전염병 예방 프로그램의 개발 및 효과에 관한 연구
# 3.작성자 : 김일옥
# 4.소속기관 : 梨花女子大學校
# 5.발표년도 : 1999
# 6.학위여부 : 국내박사
# 7.초록내용 : There are many critical developmental periods among preschool children and especially their health in this period can be the base of their health throughout their lives. Whereas, many preschool children today are not being given enough caring than in ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=a7d251c55adf78a0&keyword=전염병
#
#
# 5 번째 정보를 추출하고 있습니다============
# 1.번호 : 5
# 2.제목 : 우리나라 법정전염병 관리실태 및 예방대책에 관한 연구
# 3.작성자 : 심상숙
# 4.소속기관 : 경희대학교 대학원
# 5.발표년도 : 1994
# 6.학위여부 : 국내석사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=febe3a47256fd0e0&keyword=전염병
#
#
# 6 번째 정보를 추출하고 있습니다============
# 1.번호 : 6
# 2.제목 : 한국교회와 전염병
# 3.작성자 : 방용덕
# 4.소속기관 : 경상국립대학교 대학원
# 5.발표년도 : 2023
# 6.학위여부 : 국내박사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=f6165d2b3d84965bffe0bdc3ef48d419&keyword=전염병
#
#
# 7 번째 정보를 추출하고 있습니다============
# 1.번호 : 7
# 2.제목 : 국제법상 전염병 통제에 관한 연구
# 3.작성자 : 박진아
# 4.소속기관 : 고려대학교 대학원
# 5.발표년도 : 2012
# 6.학위여부 : 국내박사
# 7.초록내용 : The effective control of infectious diseases such as Severe Acute Respiratory Syndrome (SARS) and Influenza A (H1N1) 2009 which threaten the health of entire human race is infeasible without international cooperation because of their peculiar characte...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=049c252221f9aca1ffe0bdc3ef48d419&keyword=전염병
#
#
# 8 번째 정보를 추출하고 있습니다============
# 1.번호 : 8
# 2.제목 : 조선시대 전염병 전문의서의 간행과 판본 연구
# 3.작성자 : 김세홍
# 4.소속기관 : 인천대학교 대학원
# 5.발표년도 : 2026
# 6.학위여부 : 국내석사
# 7.초록내용 : With the heightened scholarly interest in infectious diseases following the COVID-19 pandemic, research on epidemic professional medical books from the Joseon Dynasty has been conducted actively across various related fields. However, bibliographical ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=90347fdd1d20e03dffe0bdc3ef48d419&keyword=전염병
#
#
# 9 번째 정보를 추출하고 있습니다============
# 1.번호 : 9
# 2.제목 : 항공운송을 통해 전파되는 전염병의 확산방지를 위한 국제적 대응 연구
# 3.작성자 : 최성희
# 4.소속기관 : 韓國外國語大學校 政治行政言論大學院
# 5.발표년도 : 2012
# 6.학위여부 : 국내석사
# 7.초록내용 : Today, airplanes and air travel are necessary factor of modern life, allowing for the quick and convenient transportation of both goods and passengers from one side of the world to another. Although air travel has become a important feature of modern ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=f2788816983f72aeffe0bdc3ef48d419&keyword=전염병
#
#
# 10 번째 정보를 추출하고 있습니다============
# 1.번호 : 10
# 2.제목 : NVivo 12를 활용한 항공산업 전염병 위기 대응 방안 연구 : 코로나 19를 중심으로
# 3.작성자 : 황세정
# 4.소속기관 : 한국교통대학교 글로벌융합대학원
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 항공 교통의 발달로 국가 간 이동이 편리해지면서 국내뿐만 아니라 해외로의 여행이 보편화하였다. 그러나 2020년 전례 없는 피해 규모와 확산 속도를 지닌 신종 코로나바이러스의 등장으로 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=f2021847fe303666ffe0bdc3ef48d419&keyword=전염병
#
#
# 2 페이지 내용 수집 시작합니다 =======================
#
#
# 11 번째 정보를 추출하고 있습니다============
# 1.번호 : 11
# 2.제목 : 전염병과 펜데믹 상황에서 메디컬 처치의 운영에 관한 연구
# 3.작성자 : 이재훈
# 4.소속기관 : 칼빈대학교 신학대학원
# 5.발표년도 : 2021
# 6.학위여부 : 국내석사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=2b51133ed1f648a9ffe0bdc3ef48d419&keyword=전염병
#
#
# 12 번째 정보를 추출하고 있습니다============
# 1.번호 : 12
# 2.제목 : 고등학생의 전염병 관련 과학적 소양 수준 연구
# 3.작성자 : 강보경
# 4.소속기관 : 慶尙大學校
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 과학적 소양(Scientific Literacy)은 현대 사회를 살아기는데 필수적인 수단으로 강조되고 있으며, 우리나라 제 7차 개정 과학과 교육과정의 목표로 제시되어있다. 본 연구에서는 고등학교 생명과...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=c6cab1a2133823bcffe0bdc3ef48d419&keyword=전염병
#
#
# 13 번째 정보를 추출하고 있습니다============
# 1.번호 : 13
# 2.제목 : 조선총독부의 급성전염병 예방 대책 변화 - 수인성 전염병을 중심으로
# 3.작성자 : 백선례
# 4.소속기관 : 한양대학교 대학원
# 5.발표년도 : 2021
# 6.학위여부 : 국내박사
# 7.초록내용 : 이 논문에서는 일본이 식민지 조선 통치의 정당성 부여에 적극 활용했던 근대 의학, 그 중에서도 급성전염병 예방 대책을 중점적으로 살펴보았다. 급성전염병 중에서도 식민지 조선에서 많...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=6365622b1979f82fffe0bdc3ef48d419&keyword=전염병
#
#
# 14 번째 정보를 추출하고 있습니다============
# 1.번호 : 14
# 2.제목 : 학령전 아동을 위한 호흡기전염병 예방 프로그램의 개발 및 효과에 관한 연구
# 3.작성자 : 김일옥
# 4.소속기관 : 梨花女子大學校
# 5.발표년도 : 1999
# 6.학위여부 : 국내박사
# 7.초록내용 : There are many critical developmental periods among preschool children and especially their health in this period can be the base of their health throughout their lives. Whereas, many preschool children today are not being given enough caring than in ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=a7d251c55adf78a0&keyword=전염병
#
#
# 15 번째 정보를 추출하고 있습니다============
# 1.번호 : 15
# 2.제목 : 우리나라 법정전염병 관리실태 및 예방대책에 관한 연구
# 3.작성자 : 심상숙
# 4.소속기관 : 경희대학교 대학원
# 5.발표년도 : 1994
# 6.학위여부 : 국내석사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=febe3a47256fd0e0&keyword=전염병
#
#
# 16 번째 정보를 추출하고 있습니다============
# 1.번호 : 16
# 2.제목 : 한국교회와 전염병
# 3.작성자 : 방용덕
# 4.소속기관 : 경상국립대학교 대학원
# 5.발표년도 : 2023
# 6.학위여부 : 국내박사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=f6165d2b3d84965bffe0bdc3ef48d419&keyword=전염병
#
#
# 17 번째 정보를 추출하고 있습니다============
# 1.번호 : 17
# 2.제목 : 국제법상 전염병 통제에 관한 연구
# 3.작성자 : 박진아
# 4.소속기관 : 고려대학교 대학원
# 5.발표년도 : 2012
# 6.학위여부 : 국내박사
# 7.초록내용 : The effective control of infectious diseases such as Severe Acute Respiratory Syndrome (SARS) and Influenza A (H1N1) 2009 which threaten the health of entire human race is infeasible without international cooperation because of their peculiar characte...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=049c252221f9aca1ffe0bdc3ef48d419&keyword=전염병
#
#
# 18 번째 정보를 추출하고 있습니다============
# 1.번호 : 18
# 2.제목 : 조선시대 전염병 전문의서의 간행과 판본 연구
# 3.작성자 : 김세홍
# 4.소속기관 : 인천대학교 대학원
# 5.발표년도 : 2026
# 6.학위여부 : 국내석사
# 7.초록내용 : With the heightened scholarly interest in infectious diseases following the COVID-19 pandemic, research on epidemic professional medical books from the Joseon Dynasty has been conducted actively across various related fields. However, bibliographical ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=90347fdd1d20e03dffe0bdc3ef48d419&keyword=전염병
#
#
# 19 번째 정보를 추출하고 있습니다============
# 1.번호 : 19
# 2.제목 : 항공운송을 통해 전파되는 전염병의 확산방지를 위한 국제적 대응 연구
# 3.작성자 : 최성희
# 4.소속기관 : 韓國外國語大學校 政治行政言論大學院
# 5.발표년도 : 2012
# 6.학위여부 : 국내석사
# 7.초록내용 : Today, airplanes and air travel are necessary factor of modern life, allowing for the quick and convenient transportation of both goods and passengers from one side of the world to another. Although air travel has become a important feature of modern ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=f2788816983f72aeffe0bdc3ef48d419&keyword=전염병
#
#
# 20 번째 정보를 추출하고 있습니다============
# 1.번호 : 20
# 2.제목 : NVivo 12를 활용한 항공산업 전염병 위기 대응 방안 연구 : 코로나 19를 중심으로
# 3.작성자 : 황세정
# 4.소속기관 : 한국교통대학교 글로벌융합대학원
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 항공 교통의 발달로 국가 간 이동이 편리해지면서 국내뿐만 아니라 해외로의 여행이 보편화하였다. 그러나 2020년 전례 없는 피해 규모와 확산 속도를 지닌 신종 코로나바이러스의 등장으로 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=f2021847fe303666ffe0bdc3ef48d419&keyword=전염병
#
#
# 3 페이지 내용 수집 시작합니다 =======================
#
#
# 21 번째 정보를 추출하고 있습니다============
# 1.번호 : 21
# 2.제목 : 전염병과 펜데믹 상황에서 메디컬 처치의 운영에 관한 연구
# 3.작성자 : 이재훈
# 4.소속기관 : 칼빈대학교 신학대학원
# 5.발표년도 : 2021
# 6.학위여부 : 국내석사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=2b51133ed1f648a9ffe0bdc3ef48d419&keyword=전염병
#
#
# 22 번째 정보를 추출하고 있습니다============
# 1.번호 : 22
# 2.제목 : 고등학생의 전염병 관련 과학적 소양 수준 연구
# 3.작성자 : 강보경
# 4.소속기관 : 慶尙大學校
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 과학적 소양(Scientific Literacy)은 현대 사회를 살아기는데 필수적인 수단으로 강조되고 있으며, 우리나라 제 7차 개정 과학과 교육과정의 목표로 제시되어있다. 본 연구에서는 고등학교 생명과...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=c6cab1a2133823bcffe0bdc3ef48d419&keyword=전염병
# 요청하신 작업이 모두 완료되었습니다

# %%
# Step 10. 수집된 데이터를 xlsx와 csv 형태로 저장하기
# 현재 날짜와 시간으로 폴더 만들고 파일 이름 설정하기
import os

n = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' %(n.tm_year, n.tm_mon, n.tm_mday, n.tm_hour, n.tm_min, n.tm_sec)

os.makedirs(f_dir+'RISS'+'-'+s+'-'+'학위논문')

fc_name = f_dir+'RISS'+'-'+s+'-'+'학위논문'+'\\'+'RISS'+'-'+s+'-'+'학위논문'+'.csv'
fx_name = f_dir+'RISS'+'-'+s+'-'+'학위논문'+'\\'+'RISS'+'-'+s+'-'+'학위논문'+'.xlsx'

# 데이터 프레임 생성 후 xlsx, csv 형식으로 저장하기
import pandas as pd

df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['저자']=pd.Series(author2)
df['소속(발행)기관']=pd.Series(company2)
df['날짜']=pd.Series(date2)
df['학위(논문일경우)']=pd.Series(suksa2)
df['초록(논문일경우)']=pd.Series(contents2)
df['자료URL주소']=pd.Series(full_url2)

# xls 형태로 저장하기
df.to_excel(fx_name,index=False)

# csv 형태로 저장하기
df.to_csv(fc_name,index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
